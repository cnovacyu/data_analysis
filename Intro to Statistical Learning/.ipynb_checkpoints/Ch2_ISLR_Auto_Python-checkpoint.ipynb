# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read the Auto data set and remove missing values
auto = pd.read_csv("auto.csv", na_values='?')
auto.dropna(axis=0, how='any', inplace=True)
len(auto)
# Out:
# 392

# %%
auto.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0  18.0          8         307.0       130.0    3504          12.0    70
# 1  15.0          8         350.0       165.0    3693          11.5    70
# 2  18.0          8         318.0       150.0    3436          11.0    70
# 3  16.0          8         304.0       150.0    3433          12.0    70
# 4  17.0          8         302.0       140.0    3449          10.5    70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# a) Which predictors are qualitative and quantitative?
# qualitative: name, cylinders, origin (cylinders can be considered qualitative since there are only 3 values)
# quantitative: mpg, displacement, horsepower, weight, acceleration, year

# %%
# b) What is the range of each quantitative predictor?
# *need to specify columns as it will error out for names column*
auto.iloc[:,0:8].max() - auto.iloc[:,0:8].min()
# Out:
# mpg               37.6
# cylinders          5.0
# displacement     387.0
# horsepower       184.0
# weight          3527.0
# acceleration      16.8
# year              12.0
# origin             2.0
# dtype: float64

# %%
# c) What is the mean and std dev of each quantitative predictor?
auto.iloc[:,0:8].mean()
# Out:
# mpg               23.445918
# cylinders          5.471939
# displacement     194.411990
# horsepower       104.469388
# weight          2977.584184
# acceleration      15.541327
# year              75.979592
# origin             1.576531
# dtype: float64

# %%
auto.iloc[:,0:8].std()
# Out:
# mpg               7.805007
# cylinders         1.705783
# displacement    104.644004
# horsepower       38.491160
# weight          849.402560
# acceleration      2.758864
# year              3.683737
# origin            0.805518
# dtype: float64

# %%
# d) Remove the 10th and 85th observations. What is the range, mean, std dev
# of each predictor in the subset of data that remains
auto_sub = auto.reset_index(drop=True)
auto_sub = auto.drop(auto.index[11:87])
len(auto_sub)
# Out:
# 240

# %%
auto_sub.iloc[:,0:8].max() - auto_sub.iloc[:,0:8].min()
# Out:
# mpg               33.6
# cylinders          5.0
# displacement     385.0
# horsepower       177.0
# weight          2670.0
# acceleration      16.3
# year              12.0
# origin             2.0
# dtype: float64

# %%
auto_sub.iloc[:,0:8].mean()
# Out:
# mpg               26.099167
# cylinders          5.187500
# displacement     174.958333
# horsepower        96.695833
# weight          2823.983333
# acceleration      15.790417
# year              78.216667
# origin             1.654167
# dtype: float64

# %%
auto_sub.iloc[:,0:8].std()
# Out:
# mpg               7.688708
# cylinders         1.598329
# displacement     92.734100
# horsepower       32.987813
# weight          715.719394
# acceleration      2.741062
# year              2.803713
# origin            0.844118
# dtype: float64

# %%
# e) Investigate the predictors graphically, using scatterplots 
# or other tools of your choice
# There are strong negative relationships between mpg and displacement, horsepower, and weight
# There are other strong positive and negative relationships among
# displacement, horsepower, weight, and acceleration
pd.plotting.scatter_matrix(auto_sub.iloc[:, 0:8], figsize=(10, 10))
# Out:
# array([[<AxesSubplot:xlabel='mpg', ylabel='mpg'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='mpg'>,
#         <AxesSubplot:xlabel='displacement', ylabel='mpg'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='mpg'>,
#         <AxesSubplot:xlabel='weight', ylabel='mpg'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='mpg'>,
#         <AxesSubplot:xlabel='year', ylabel='mpg'>,
#         <AxesSubplot:xlabel='origin', ylabel='mpg'>],
#        [<AxesSubplot:xlabel='mpg', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='cylinders', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='displacement', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='horsepower', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='weight', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='acceleration', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='year', ylabel='cylinders'>,
#         <AxesSubplot:xlabel='origin', ylabel='cylinders'>],
# ...

# %%
# checking to see how strong the relationships are between the variables
auto_sub.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.746644     -0.783340   -0.776737 -0.843493
# cylinders    -0.746644   1.000000      0.939742    0.815046  0.869225
# displacement -0.783340   0.939742      1.000000    0.889920  0.920966
# horsepower   -0.776737   0.815046      0.889920    1.000000  0.845906
# weight       -0.843493   0.869225      0.920966    0.845906  1.000000
# acceleration  0.376987  -0.417891     -0.458906   -0.657862 -0.301112
# year          0.563467  -0.438601     -0.476084   -0.515871 -0.396233
# origin        0.527112  -0.494451     -0.567091   -0.424974 -0.553627
#
#               acceleration      year    origin
# mpg               0.376987  0.563467  0.527112
# cylinders        -0.417891 -0.438601 -0.494451
# displacement     -0.458906 -0.476084 -0.567091
# horsepower       -0.657862 -0.515871 -0.424974
# weight           -0.301112 -0.396233 -0.553627
# acceleration      1.000000  0.380998  0.157515
# ...

# %%
# mpg decreases as weight increases - a heavy weighted car will get less gas mileage
plt.scatter(auto_sub['weight'], auto_sub['mpg'])

# %%
# in general, mpg has been improving each year, however there is a lot of
# variance by car
plt.scatter(auto_sub['year'], auto_sub['mpg'])

# %%
# there is a strong positive relationship between weight and horsepower
# the heavier a car is, the more horsepower it tends to have
plt.scatter(auto_sub['weight'], auto_sub['horsepower'])

# %%
# there is a lot of variance in mpg
auto_sub.hist(column='mpg', bins=100, grid=False)
# Out:
# array([[<AxesSubplot:title={'center':'mpg'}>]], dtype=object)

# %%
# f) do any of your plots suggest that any other variables might be useful
# in predicting mpg?
# Yes, there are strong negative relationships between mpg and 
# displacement, horsepower, and weight
